# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/DLProj/diffusiondet/DiffusionDet
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1OZN46fcF9ditlFKQ2RjrwpJ74cWVjVKG/DLProj/diffusiondet/DiffusionDet

# %%
# !git clone https://github.com/facebookresearch/detectron2 detectron2_repo
# !pip install -e detectron2_repo

# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# ...
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-8oa3mx8v
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-8oa3mx8v
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 181aae36820af025eed1e33e58390f7ed9261e1a
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 20.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 17.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# from detectron2.data import DatasetCatalog, MetadataCatalog
# from detectron2.data.datasets import register_coco_instances

# # Provide the path to the JSON file and the directory where the images are stored
# register_coco_instances("my_data_train", {}, "/content/drive/MyDrive/diffusiondet/train/_annotations.coco.json", "/content/drive/MyDrive/diffusiondet/train")

# register_coco_instances("my_data_valid", {}, "/content/drive/MyDrive/diffusiondet/valid/_annotations.coco.json", "/content/drive/MyDrive/diffusiondet/valid")

# %%
# import cv2
# import random
# from google.colab.patches import cv2_imshow
# from detectron2.utils.visualizer import Visualizer
# from detectron2.data import DatasetCatalog, MetadataCatalog
# from detectron2.data.datasets import register_coco_instances

# def visualize_data(types):
#   dataset_dicts = DatasetCatalog.get(f"my_data_{types}")
#   for d in random.sample(dataset_dicts, 3):
#       img = cv2.imread(d["file_name"])
#       visualizer = Visualizer(img[:, :, ::-1], metadata=MetadataCatalog.get(f"my_data_{types}"), scale=0.5)
#       vis = visualizer.draw_dataset_dict(d)
#       cv2_imshow(vis.get_image()[:, :, ::-1])
#       cv2.waitKey(0)
#       cv2.destroyAllWindows()
# visualize_data("train")
# visualize_data("valid")

# print(DatasetCatalog.list())

# %%
# !git clone https://github.com/ShoufaChen/DiffusionDet.git
# # %cd DiffusionDet

# %%
# import os

# Set the environment variable
# os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

# Now you can run your code that uses PyTorch

# %%
# !pip install timm
# !python /content/drive/MyDrive/DLProj/diffusiondet/DiffusionDet/train_net.py --num-gpus 1 \
    --config-file /content/drive/MyDrive/DLProj/diffusiondet/diffdet.mydataset.res50.yaml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 10.8 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# !python demo.py --config-file configs/diffdet.mydataset.res50.yaml \
#     --input /content/sample_image.jpg --opts MODEL.WEIGHTS /path/to/model_weights.pth

# !python train_net.py --num-gpus 1 \
    --config-file /content/drive/MyDrive/DLProj/diffusiondet/diffdet.mydataset.res50.yaml \
    --eval-only MODEL.WEIGHTS /content/drive/MyDrive/DLProj/output/output/model_0044999.pth
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 16.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
import os
os.environ['QT_QPA_PLATFORM'] = 'offscreen'

# %%
# !python /content/drive/MyDrive/DLProj/diffusiondet/DiffusionDet/demo.py --config-file /content/drive/MyDrive/DLProj/diffusiondet/DiffusionDet/output/config.yaml \
    --input /content/drive/MyDrive/DLProj/diffusiondet/valid/004928_jpg.rf.4395ab2f89ecfe933c6cf9538866c54f.jpg --opts MODEL.WEIGHTS /content/drive/MyDrive/DLProj/diffusiondet/DiffusionDet/output/model_0004999.pth
# Out:
# [04/16 10:57:18 detectron2]: Arguments: Namespace(config_file='/content/drive/MyDrive/DLProj/diffusiondet/DiffusionDet/output/config.yaml', webcam=False, video_input=None, input=['/content/drive/MyDrive/DLProj/diffusiondet/valid/004928_jpg.rf.4395ab2f89ecfe933c6cf9538866c54f.jpg'], output=None, confidence_threshold=0.5, opts=['MODEL.WEIGHTS', '/content/drive/MyDrive/DLProj/diffusiondet/DiffusionDet/output/model_0004999.pth'])
# [04/16 10:57:20 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /content/drive/MyDrive/DLProj/diffusiondet/DiffusionDet/output/model_0004999.pth ...
# [04/16 10:57:20 fvcore.common.checkpoint]: [Checkpointer] Loading from /content/drive/MyDrive/DLProj/diffusiondet/DiffusionDet/output/model_0004999.pth ...
# [04/16 10:57:23 detectron2]: /content/drive/MyDrive/DLProj/diffusiondet/valid/004928_jpg.rf.4395ab2f89ecfe933c6cf9538866c54f.jpg: detected 1 instances in 1.08s
# ...
